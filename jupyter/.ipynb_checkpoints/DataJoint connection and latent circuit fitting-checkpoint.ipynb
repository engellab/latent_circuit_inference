# %%
import sys
sys.path.append("../../")
import numpy as np
from matplotlib import pyplot as plt
import json
import pickle
import os
import torch
from rnn_coach.src.RNN_torch import *
from rnn_coach.src.DynamicSystemAnalyzer import *
from rnn_coach.src.RNN_numpy import *
from rnn_coach.src.Task import *
from rnn_coach.src.DataSaver import *
from latent_circuit_inference.src.LatentCircuit import *
from latent_circuit_inference.src.LatentCircuitFitter import *
from latent_circuit_inference.src.LCAnalyzer import *
from latent_circuit_inference.src.utils import *
from latent_circuit_inference.src.circuit_vizualization import *
import time

def mse_scoring(x, y):
    return np.mean((x - y) ** 2)

def R2(x, y):
    return 1.0 - mse_scoring(x, y)/np.var(y)

# %%
# if with datajoint
# rnn_dj  = RNNDJ()
# task_dj  = TaskDJ()
# trainer_dj  = TrainerDJ()
# networks_sorted = (rnn_dj & "activation_name = 'relu'").fetch("rnn_hash", order_by='mse_score')
# top_50_RNNs = networks_sorted[:50]
# top_RNN = top_50_RNNs[0]
# rnn_data = pd.DataFrame((rnn_dj & f"rnn_hash = '{top_RNN}'").fetch())
# task_string = rnn_data["task_hash"][0]
# task_data = pd.DataFrame((task_dj & f"task_hash='{task_string}'").fetch())
# trainer_string = rnn_data["trainer_hash"][0]
# trainer_data = pd.DataFrame((trainer_dj & f"trainer_hash='{trainer_string}'").fetch())

# %%
#given the folder, open up the files:
RNN_folder = "0.0073745_20230222-064341"

tag = '8-nodes'
RNN_folder_full_path = os.path.join("../", "../", "rnn_coach", "data", "trained_RNNs", "CDDM", RNN_folder)
mse_score_RNN = os.listdir(RNN_folder_full_path)[0].split("_")[0]
rnn_config = json.load(open(os.path.join(RNN_folder_full_path, f"{mse_score_RNN}_config.json"), "rb+"))
rnn_data = json.load(open(os.path.join(RNN_folder_full_path, f"{mse_score_RNN}_params_CDDM.json"), "rb+"))

# %% [markdown]
# # Latent Circuit Inference set up

# %%
LCI_config_file = json.load(open(os.path.join("../", "data", "configs", f"LCI_config.json"), mode="r", encoding='utf-8'))
task_data = rnn_config["task_params"]

# %%
# defining RNN:
activation_name = rnn_config["activation"]
RNN_N = rnn_config["N"]
if activation_name == 'relu':
    activation_RNN = lambda x: torch.maximum(x, torch.tensor(0))
elif activation_name == 'tanh':
    activation_RNN = torch.tanh
elif activation_name == 'sigmoid':
    activation_RNN = lambda x: 1/(1 + torch.exp(-x))
elif activation_name == 'softplus':
    activation_RNN = lambda x: torch.log(1 + torch.exp(5 * x))
dt = rnn_config["dt"]
tau = rnn_config["tau"]
connectivity_density_rec = rnn_config["connectivity_density_rec"]
spectral_rad = rnn_config["sr"]
sigma_inp = rnn_config["sigma_inp"]
sigma_rec = rnn_config["sigma_rec"]
# seed = LCI_config_file["seed"]
seed = np.random.randint(1000000)
print(f"seed: {seed}")
if torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')
rng = torch.Generator(device=torch.device('cpu'))
if not seed is None:
    rng.manual_seed(seed)
input_size = np.array(rnn_data["W_inp"]).shape[1]
output_size = np.array(rnn_data["W_out"]).shape[0]
# Out:
# seed: 348397

# %%
# Task:
n_steps = task_data["n_steps"]

# %%
# LC
n = LCI_config_file["n"]
LC_N = LCI_config_file["N"]
W_inp = np.array(LCI_config_file["W_inp"])
W_out = np.array(LCI_config_file["W_out"])
# Fitter:
lambda_w = 0.09 # LCI_config_file["lambda_w"]
max_iter = 1000 # LCI_config_file["max_iter"]
tol = LCI_config_file["tol"]
lr = 0.1 #LCI_config_file["lr"]
actvation_name = LCI_config_file["activation"]
inp_connectivity_mask = np.array(LCI_config_file["inp_connectivity_mask"])
rec_connectivity_mask = np.array(LCI_config_file["rec_connectivity_mask"])
out_connectivity_mask = np.array(LCI_config_file["out_connectivity_mask"])
if activation_name == 'relu':
    activation_LC = lambda x: torch.maximum(x, torch.tensor(0))
elif activation_name == 'tanh':
    activation_LC = torch.tanh
elif activation_name == 'sigmoid':
    activation_LC = lambda x: 1/(1 + torch.exp(-x))
elif activation_name == 'softplus':
    activation_LC = lambda x: torch.log(1 + torch.exp(5 * x))

# %%
# # creating instances:
rnn_torch = RNN_torch(N=RNN_N, dt=dt, tau=tau, input_size=input_size, output_size=output_size,
                      activation=activation_RNN, random_generator=rng, device=device)
RNN_params = {"W_inp":np.array(rnn_data["W_inp"]),
              "W_rec":np.array(rnn_data["W_rec"]),
              "W_out":np.array(rnn_data["W_out"]),
              "b_rec":np.array(rnn_data["bias_rec"]),
              "y_init":np.zeros(RNN_N)}
rnn_torch.set_params(RNN_params)

lc = LatentCircuit(n=n,
                   N=LC_N,
                   W_inp=torch.Tensor(W_inp),
                   W_out=torch.Tensor(W_out),
                   inp_connectivity_mask=inp_connectivity_mask,
                   rec_connectivity_mask=rec_connectivity_mask,
                   out_connectivity_mask=out_connectivity_mask,
                   activation=activation_LC,
                   device=device,
                   random_generator=rng)

task = TaskCDDM(n_steps=n_steps, n_inputs=input_size, n_outputs=output_size, task_params=task_data)
criterion = torch.nn.MSELoss()
optimizer = torch.optim.Adam(lc.parameters(), lr=lr)
fitter = LatentCircuitFitter(LatentCircuit=lc, RNN=rnn_torch, Task=task,
                             max_iter=max_iter, tol=tol,
                             optimizer=optimizer, criterion=criterion,
                             lambda_w=lambda_w)
# Out:
# Using cpu for RNN!
# Using cpu for Latent Circuit!

# %%
tic = time.perf_counter()
lc_inferred, train_losses, val_losses, net_params = fitter.run_training()
toc = time.perf_counter()
print(f"Executed training in {toc - tic:0.4f} seconds")
# Out:
# iteration 0, train loss: 2.635154, validation loss: 0.486278
# iteration 1, train loss: 2.133801, validation loss: 0.411245
# iteration 2, train loss: 1.786952, validation loss: 0.358686
# iteration 3, train loss: 1.537636, validation loss: 0.350893
# iteration 4, train loss: 1.533285, validation loss: 0.341256
# iteration 5, train loss: 1.506661, validation loss: 0.324649
# iteration 6, train loss: 1.416887, validation loss: 0.323392
# iteration 7, train loss: 1.40567, validation loss: 0.32732
# iteration 8, train loss: 1.421813, validation loss: 0.328234
# iteration 9, train loss: 1.42445, validation loss: 0.324368
# iteration 10, train loss: 1.404034, validation loss: 0.316866
# iteration 11, train loss: 1.367298, validation loss: 0.308403
# iteration 12, train loss: 1.329442, validation loss: 0.3035
# iteration 13, train loss: 1.317912, validation loss: 0.302411
# iteration 14, train loss: 1.322631, validation loss: 0.298236
# iteration 15, train loss: 1.3047, validation loss: 0.294188
# iteration 16, train loss: 1.275329, validation loss: 0.293943
# iteration 17, train loss: 1.267952, validation loss: 0.294312
# iteration 18, train loss: 1.265834, validation loss: 0.292133
# iteration 19, train loss: 1.259335, validation loss: 0.287321
# iteration 20, train loss: 1.237411, validation loss: 0.281223
# iteration 21, train loss: 1.214221, validation loss: 0.275952
# iteration 22, train loss: 1.191583, validation loss: 0.272556
# iteration 23, train loss: 1.179572, validation loss: 0.269238
# iteration 24, train loss: 1.163817, validation loss: 0.264916
# iteration 25, train loss: 1.14157, validation loss: 0.260651
# iteration 26, train loss: 1.11904, validation loss: 0.256954
# iteration 27, train loss: 1.097023, validation loss: 0.254594
# iteration 28, train loss: 1.085342, validation loss: 0.251598
# iteration 29, train loss: 1.066508, validation loss: 0.248717
# iteration 30, train loss: 1.058626, validation loss: 0.245202
# iteration 31, train loss: 1.040897, validation loss: 0.241399
# iteration 32, train loss: 1.031987, validation loss: 0.242945
# iteration 33, train loss: 1.037184, validation loss: 0.263402
# iteration 34, train loss: 1.123759, validation loss: 0.227917
# iteration 35, train loss: 0.983015, validation loss: 0.248922
# iteration 36, train loss: 1.057763, validation loss: 0.233754
# iteration 37, train loss: 1.000076, validation loss: 0.226454
# iteration 38, train loss: 0.983311, validation loss: 0.228246
# iteration 39, train loss: 1.000539, validation loss: 0.216424
# iteration 40, train loss: 0.948244, validation loss: 0.213017
# iteration 41, train loss: 0.926326, validation loss: 0.214756
# iteration 42, train loss: 0.93578, validation loss: 0.20266
# iteration 43, train loss: 0.890287, validation loss: 0.205405
# iteration 44, train loss: 0.910543, validation loss: 0.19206
# iteration 45, train loss: 0.838035, validation loss: 0.201753
# iteration 46, train loss: 0.870791, validation loss: 0.186284
# iteration 47, train loss: 0.807616, validation loss: 0.196616
# iteration 48, train loss: 0.847796, validation loss: 0.176381
# iteration 49, train loss: 0.765472, validation loss: 0.187815
# iteration 50, train loss: 0.818816, validation loss: 0.174301
# iteration 51, train loss: 0.756255, validation loss: 0.168426
# iteration 52, train loss: 0.736058, validation loss: 0.180798
# iteration 53, train loss: 0.780862, validation loss: 0.158469
# iteration 54, train loss: 0.691581, validation loss: 0.177141
# iteration 55, train loss: 0.761786, validation loss: 0.164898
# iteration 56, train loss: 0.741352, validation loss: 0.15077
# iteration 57, train loss: 0.661658, validation loss: 0.169786
# iteration 58, train loss: 0.732139, validation loss: 0.149609
# iteration 59, train loss: 0.647412, validation loss: 0.156709
# iteration 60, train loss: 0.695617, validation loss: 0.144458
# iteration 61, train loss: 0.626933, validation loss: 0.155499
# iteration 62, train loss: 0.661547, validation loss: 0.137666
# iteration 63, train loss: 0.62165, validation loss: 0.135944
# iteration 64, train loss: 0.586314, validation loss: 0.132772
# iteration 65, train loss: 0.581172, validation loss: 0.129686
# iteration 66, train loss: 0.582905, validation loss: 0.147096
# iteration 67, train loss: 0.600252, validation loss: 0.125489
# iteration 68, train loss: 0.61475, validation loss: 0.179576
# iteration 69, train loss: 0.750366, validation loss: 0.175921
# iteration 70, train loss: 0.7305, validation loss: 0.119846
# iteration 71, train loss: 0.555953, validation loss: 0.140504
# iteration 72, train loss: 0.642871, validation loss: 0.124045
# iteration 73, train loss: 0.536309, validation loss: 0.185708
# iteration 74, train loss: 0.795823, validation loss: 0.179276
# iteration 75, train loss: 0.775885, validation loss: 0.124363
# iteration 76, train loss: 0.588565, validation loss: 0.124046
# iteration 77, train loss: 0.573207, validation loss: 0.140613
# iteration 78, train loss: 0.583802, validation loss: 0.134574
# iteration 79, train loss: 0.569141, validation loss: 0.142473
# iteration 80, train loss: 0.627168, validation loss: 0.145992
# iteration 81, train loss: 0.596807, validation loss: 0.118489
# iteration 82, train loss: 0.541503, validation loss: 0.116987
# iteration 83, train loss: 0.556021, validation loss: 0.153251
# iteration 84, train loss: 0.591698, validation loss: 0.122017
# iteration 85, train loss: 0.497774, validation loss: 0.188068
# iteration 86, train loss: 0.855984, validation loss: 0.145226
# iteration 87, train loss: 0.640474, validation loss: 0.163127
# iteration 88, train loss: 0.731275, validation loss: 0.155451
# iteration 89, train loss: 0.657463, validation loss: 0.142564
# iteration 90, train loss: 0.63746, validation loss: 0.152061
# iteration 91, train loss: 0.684983, validation loss: 0.150006
# iteration 92, train loss: 0.683602, validation loss: 0.14169
# iteration 93, train loss: 0.642114, validation loss: 0.137186
# iteration 94, train loss: 0.593525, validation loss: 0.137772
# iteration 95, train loss: 0.591189, validation loss: 0.144259
# iteration 96, train loss: 0.609363, validation loss: 0.121142
# iteration 97, train loss: 0.540695, validation loss: 0.125626
# iteration 98, train loss: 0.61261, validation loss: 0.145604
# iteration 99, train loss: 0.623415, validation loss: 0.114218
# iteration 100, train loss: 0.534374, validation loss: 0.111221
# iteration 101, train loss: 0.55155, validation loss: 0.121452
# iteration 102, train loss: 0.508663, validation loss: 0.120638
# iteration 103, train loss: 0.508006, validation loss: 0.108614
# iteration 104, train loss: 0.483364, validation loss: 0.109504
# iteration 105, train loss: 0.517971, validation loss: 0.098322
# iteration 106, train loss: 0.453485, validation loss: 0.122271
# iteration 107, train loss: 0.489674, validation loss: 0.100033
# iteration 108, train loss: 0.475967, validation loss: 0.132693
# iteration 109, train loss: 0.62043, validation loss: 0.113319
# iteration 110, train loss: 0.458798, validation loss: 0.141757
# iteration 111, train loss: 0.62785, validation loss: 0.129279
# iteration 112, train loss: 0.593319, validation loss: 0.104337
# iteration 113, train loss: 0.511301, validation loss: 0.120395
# iteration 114, train loss: 0.530916, validation loss: 0.145561
# iteration 115, train loss: 0.596158, validation loss: 0.123604
# iteration 116, train loss: 0.531911, validation loss: 0.125296
# iteration 117, train loss: 0.563433, validation loss: 0.113089
# iteration 118, train loss: 0.492727, validation loss: 0.129376
# iteration 119, train loss: 0.546042, validation loss: 0.111802
# iteration 120, train loss: 0.516812, validation loss: 0.110471
# iteration 121, train loss: 0.507581, validation loss: 0.112326
# iteration 122, train loss: 0.498166, validation loss: 0.106852
# iteration 123, train loss: 0.475561, validation loss: 0.106065
# iteration 124, train loss: 0.485841, validation loss: 0.120442
# iteration 125, train loss: 0.491151, validation loss: 0.103131
# iteration 126, train loss: 0.461058, validation loss: 0.097044
# iteration 127, train loss: 0.464204, validation loss: 0.110246
# iteration 128, train loss: 0.484071, validation loss: 0.089396
# iteration 129, train loss: 0.429568, validation loss: 0.098255
# iteration 130, train loss: 0.457637, validation loss: 0.102197
# iteration 131, train loss: 0.425066, validation loss: 0.100398
# iteration 132, train loss: 0.422495, validation loss: 0.087132
# iteration 133, train loss: 0.448529, validation loss: 0.116329
# iteration 134, train loss: 0.508469, validation loss: 0.107146
# iteration 135, train loss: 0.433201, validation loss: 0.109613
# iteration 136, train loss: 0.535181, validation loss: 0.08987
# iteration 137, train loss: 0.452299, validation loss: 0.113502
# iteration 138, train loss: 0.471496, validation loss: 0.112034
# iteration 139, train loss: 0.512462, validation loss: 0.098096
# iteration 140, train loss: 0.435481, validation loss: 0.107277
# iteration 141, train loss: 0.438178, validation loss: 0.100751
# iteration 142, train loss: 0.465488, validation loss: 0.098193
# iteration 143, train loss: 0.473905, validation loss: 0.101252
# iteration 144, train loss: 0.424456, validation loss: 0.09148
# iteration 145, train loss: 0.4092, validation loss: 0.095541
# iteration 146, train loss: 0.446438, validation loss: 0.094041
# iteration 147, train loss: 0.439745, validation loss: 0.100513
# iteration 148, train loss: 0.421193, validation loss: 0.088819
# iteration 149, train loss: 0.420067, validation loss: 0.088859
# iteration 150, train loss: 0.425803, validation loss: 0.092109
# iteration 151, train loss: 0.390693, validation loss: 0.08418
# iteration 152, train loss: 0.374551, validation loss: 0.08344
# iteration 153, train loss: 0.381911, validation loss: 0.079427
# iteration 154, train loss: 0.363939, validation loss: 0.071165
# iteration 155, train loss: 0.349109, validation loss: 0.099764
# iteration 156, train loss: 0.432135, validation loss: 0.067393
# iteration 157, train loss: 0.365504, validation loss: 0.078822
# iteration 158, train loss: 0.359651, validation loss: 0.077507
# iteration 159, train loss: 0.344066, validation loss: 0.069534
# iteration 160, train loss: 0.359517, validation loss: 0.088288
# iteration 161, train loss: 0.359629, validation loss: 0.069061
# iteration 162, train loss: 0.327532, validation loss: 0.082494
# iteration 163, train loss: 0.423829, validation loss: 0.097172
# iteration 164, train loss: 0.426272, validation loss: 0.078124

# %%
# # save the data so that you dont do it again!
# file = f'{top_RNN}_LCI_data_example.pkl'
# pickle.dump(net_params, open(os.path.join("./", file), 'wb+'))

# %%
# file = f'{top_RNN}_LCI_data_example.pkl'
# net_params = pickle.load(open(os.path.join("./", file), 'rb+'))

# %%
# defining circuit
n = LCI_config_file["n"]
U = net_params["U"]
q = net_params["q"]
Q = q @ U
W_rec = RNN_params["W_rec"]
w_rec_bar = Q @ W_rec @ Q.T
w_rec = net_params["W_rec"]
names = ["ctx m", "ctx c", "mr", "ml", "cr", "cl", "OutR", "OutL"]
w_rec = net_params["W_rec"]
w_inp = net_params["W_inp"]
w_out = net_params["W_out"]
dt = net_params["dt"]
tau = net_params["tau"]
activation_fun_circuit = lambda x: np.maximum(0, x)
circuit = RNN_numpy(N=n, W_rec=w_rec, W_inp=w_inp, W_out=w_out, dt=dt, tau=tau, activation=activation_fun_circuit)
circuit.y = np.zeros(n)

# %%
# defining RNN
N = rnn_data["N"]
x = np.random.randn(n)
W_rec = RNN_params["W_rec"]
W_inp = RNN_params["W_inp"]
W_out = RNN_params["W_out"]
dt = net_params["dt"]
tau = net_params["tau"]
activation_fun_RNN = lambda x: np.maximum(0, x)
RNN = RNN_numpy(N=N, W_rec=W_rec, W_inp=W_inp, W_out=W_out, dt=dt, tau=tau, activation=activation_fun_RNN)
RNN.y = np.zeros(n)

# %%
# defining analyzer
node_labels = ['ctx m', "ctx c", "mR", "mL", "cR", "cL", "OutR", "OutL"]
analyzer = LCAnalyzer(circuit, labels=node_labels)
input_batch_valid, target_batch_valid, conditions_valid = task.get_batch()
mask = np.array(rnn_config["mask"])

# %%
#MSE mse_score_RNN
score_function = lambda x, y: np.mean((x - y) ** 2)
mse_score = analyzer.get_validation_score(scoring_function=mse_scoring,
                                          input_batch=input_batch_valid,
                                          target_batch=target_batch_valid,
                                          mask=mask,
                                          sigma_rec=sigma_rec,
                                          sigma_inp=sigma_inp)
mse_score = np.round(mse_score, 8)
print(f"MSE: {mse_score}")
# Out:
# MSE: 0.04742143

# %%
# Total variance
batch_size = input_batch_valid.shape[2]
RNN.clear_history()
circuit.clear_history()
RNN_trajectories, RNN_output = RNN.run_multiple_trajectories(input_timeseries=input_batch_valid, sigma_rec=0, sigma_inp=0)
lc_trajectories, lc_output = circuit.run_multiple_trajectories(input_timeseries=input_batch_valid, sigma_rec=0, sigma_inp=0)

# %%
lc_trajectories_emb = np.swapaxes(Q.T @ np.swapaxes(lc_trajectories, 0, 1), 0, 1)
RNN_trajectories_proj = np.swapaxes(Q @ np.swapaxes(RNN_trajectories, 0, 1), 0, 1)
r2_tot = np.mean([R2(lc_trajectories_emb[:, mask, i], RNN_trajectories[:, mask, i]) for i in range(batch_size)])
r2_proj = np.mean([R2(lc_trajectories[:, mask, i], RNN_trajectories_proj[:, mask, i]) for i in range(batch_size)])
print(f"Total R2: {r2_tot}")
print(f"Projected R2: {r2_proj}")
scores = {"mse_score": mse_score, "r2_tot":r2_tot, "r2_proj" : r2_proj}
# Out:
# Total R2: 0.8255032276522423
# Projected R2: 0.9133106923234574

# %%
data_folder = os.path.join(LCI_config_file["data_folder"], RNN_folder, f"{mse_score}_LC_{tag}")
datasaver = DataSaver(data_folder)
datasaver.save_data(scores, f"{mse_score}_LC_scores.pkl")
datasaver.save_data(LCI_config_file, f"{mse_score}_LC_config.json")
datasaver.save_data(net_params, f"{mse_score}_LC_params.pkl")

# %%
w_rec = net_params["W_rec"]
fig_w_rec = analyzer.plot_recurrent_matrix()
datasaver.save_figure(fig_w_rec, f"{mse_score}_LC_wrec.png")
plt.show()

# %%
def plot_recurrent_matrix(w_rec):
    fig_w_rec = plt.figure()
    ax = plt.gca()
    labels = []
    im = ax.imshow(w_rec, interpolation='blackman', cmap=cmap)
    fig_w_rec.colorbar(im)
    ax.set_xticks(np.arange(n))
    ax.set_xticklabels(labels)
    ax.set_yticks(np.arange(n))
    ax.set_yticklabels(labels)
    ax.tick_params(axis="x", bottom=False, top=True, labelbottom=False, labeltop=True)
    plt.setp([tick.label1 for tick in ax.xaxis.get_major_ticks()], rotation=45,
             ha="right", va="center", rotation_mode="anchor")
    plt.setp([tick.label2 for tick in ax.xaxis.get_major_ticks()], rotation=45,
             ha="left", va="center", rotation_mode="anchor")

    for (i, j), z in np.ndenumerate(w_rec):
        if np.abs(z) >= 0.05:
            if z >= -1:
                ax.text(j, i, str(np.round(z, 2)), ha="center", va="center", color='k')
            if z < -1:
                ax.text(j, i, str(np.round(z, 2)), ha="center", va="center", color='w')
    # ax.set_title("Connectivity matrix", fontsize = 16, pad=10)
    im = ax.imshow(w_rec, interpolation='none', vmin=-np.max(np.abs(w_rec)), vmax=np.max(np.abs(w_rec)), cmap=cmap)
    fig_w_rec.tight_layout()
    return fig_w_rec

fig_w_rec = plot_recurrent_matrix(w_rec_bar)
plt.show()

# %%
np.round(net_params["W_out"], 3)
# Out:
# array([[ 0.   , -0.   ,  0.   ,  0.   ,  0.   ,  0.   ,  0.58 ,  0.   ],
#        [ 0.   , -0.   ,  0.   ,  0.   , -0.   , -0.   ,  0.   ,  0.626]],
#       dtype=float32)

# %%
fig_w_rec_comparison = analyzer.plot_recurrent_matrix_comparison(w_rec_bar=w_rec_bar)
datasaver.save_figure(fig_w_rec_comparison, f"{mse_score}_LC_wrec_comparison.png")
plt.show()

# %%
fig_circuit_graph = analyzer.plot_circuit_graph()
datasaver.save_figure(fig_circuit_graph, f"{mse_score}_circuit_graph.png")
plt.show()

# %%
def plot_trials(circuit, input_batch, target_batch, mask, sigma_rec=0.03, sigma_inp=0.03, labels=None, rng_numpy=None):
    n_inputs = input_batch.shape[0]
    n_steps = input_batch.shape[1]
    batch_size = input_batch.shape[2]
#     fig_output, axes = plt.subplots(batch_size, 1, figsize=(7, 8))
    fig = plt.figure()
    circuit.clear_history()
    circuit.run_multiple_trajectories(input_timeseries=input_batch,
                                       sigma_rec=0,
                                       sigma_inp=0,
                                       generator_numpy=rng_numpy)
    predicted_output = np.swapaxes((circuit.W_out @ circuit.y_history), 0, 1)
    print(predicted_output.shape)
    plt.plot(predicted_output[:, :, 0].T)
#     colors = ["r", "b", "g", "c", "m", "y", 'k']
#     n_outputs = circuit.W_out.shape[0]
#     for k in range(batch_size):
#         for i in range(n_outputs):
#             tag = labels[i] if not (labels is None) else ''
#             axes[k].plot(predicted_output[i, :, k], color=colors[i], label=f'predicted {tag}')
#             axes[k].plot(mask, target_batch[i, mask, k], color=colors[i], linestyle='--', label=f'target {tag}')
#         axes[k].spines.right.set_visible(False)
#         axes[k].spines.top.set_visible(False)

# %%
print(f"Plotting random trials")
inds = np.random.choice(np.arange(input_batch_valid.shape[-1]), 20)
inputs = input_batch_valid[..., inds]
targets = target_batch_valid[..., inds]
circuit.y_init = np.zeros(8)
# fig_trials = analyzer.plot_trials(inputs, targets, mask, sigma_rec=0, sigma_inp=0)
# datasaver.save_figure(fig_trials, f"{mse_score}_LC_random_trials.png")
# plt.show()
plot_trials(circuit, inputs, targets, mask, sigma_rec=0.03, sigma_inp=0.03, labels=None, rng_numpy=None)
# Out:
# Plotting random trials
# (2, 750, 20)

# %%
num_levels = len(task_data["coherences"])
analyzer.calc_psychometric_data(task, mask, num_levels=num_levels, num_repeats=31, sigma_rec=0.03, sigma_inp=0.03)
fig_psycho = analyzer.plot_psychometric_data()
datasaver.save_figure(fig_psycho, f"{mse_score}_LC_psychometric.png")
datasaver.save_data(analyzer.psychometric_data, f"{mse_score}_psycho_data.pkl")
plt.show()

# %%
print(f"Analyzing fixed points")
dsa = DynamicSystemAnalyzerCDDM(circuit)
params = {"fun_tol": 0.05,
          "diff_cutoff": 1e-4,
          "sigma_init_guess": 15,
          "patience": 100,
          "stop_length": 100,
          "mode": "approx"}
dsa.get_fixed_points(Input=np.array([1, 0, 0.5, 0.5, 0.5, 0.5]), **params)
dsa.get_fixed_points(Input=np.array([0, 1, 0.5, 0.5, 0.5, 0.5]), **params)
print(f"Calculating Line Attractor analytics")
dsa.calc_LineAttractor_analytics(nudge=0.1)
fig_LA3D = dsa.plot_LineAttractor_3D()
datasaver.save_figure(fig_LA3D, f"{mse_score}_LC_LA3D.png")
datasaver.save_data(dsa.fp_data, f"{mse_score}_fp_data.pkl")
datasaver.save_data(dsa.LA_data, f"{mse_score}_LA_data.pkl")
plt.show()
# Out:
# Analyzing fixed points
# Calculating Line Attractor analytics
# Analyzing points on a line attractor in motion context...
#   0%|          | 0/31 [00:00<?, ?it/s]
# Analyzing points on a line attractor in color context...
#   0%|          | 0/31 [00:00<?, ?it/s]

# %%
LA_data_lc = pickle.load(open(os.path.join(data_folder, f"{mse_score}_LA_data.pkl"), "rb+"))
LA_data_RNN = pickle.load(open(os.path.join(RNN_folder_full_path, f"{mse_score_RNN}_LA_data.pkl"), "rb+"))
fig_selection_vects = analyzer.plot_selection_vectors(Q, LA_data_lc, LA_data_RNN)
datasaver.save_figure(fig_selection_vects, f"{mse_score}_selection_vects_comparison.png")
plt.show()
