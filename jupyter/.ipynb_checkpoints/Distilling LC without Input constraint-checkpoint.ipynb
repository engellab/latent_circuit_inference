# %%
import sys
from copy import deepcopy
from geoopt.optim import RiemannianAdam
sys.path.append("./")
sys.path.append("../")
sys.path.append("../../")
import numpy as np
import json
import pickle
import os
import torch
from rnn_coach.src.RNN_torch import *
from rnn_coach.src.DynamicSystemAnalyzer import *
from rnn_coach.src.RNN_numpy import *
from rnn_coach.src.Task import *
from rnn_coach.src.DataSaver import *
from src.utils import jsonify
from latent_circuit_inference.src.LatentCircuit import *
from latent_circuit_inference.src.LatentCircuitFitter import *
from latent_circuit_inference.src.LCAnalyzer import *
from latent_circuit_inference.src.utils import *
from latent_circuit_inference.src.circuit_vizualization import *
from matplotlib import pyplot as plt

# %%
def mse_scoring(x, y):
    return np.mean((x - y) ** 2)

def R2(x, y):
    return 1.0 - mse_scoring(x, y)/np.var(y)

RNN_folder = "0.0073745_CDDM;relu;N=100;lmbdo=0.3;lmbdr=0.1;lr=0.002;maxiter=3000"
tag = '8nodes'

disp = False
RNN_folder_full_path = os.path.join("../", "../", "rnn_coach", "data", "trained_RNNs", "CDDM", RNN_folder)
mse_score_RNN = os.listdir(RNN_folder_full_path)[2].split("_")[0]
rnn_config = json.load(open(os.path.join(RNN_folder_full_path, f"{mse_score_RNN}_config.json"), "rb+"))
rnn_data = json.load(open(os.path.join(RNN_folder_full_path, f"{mse_score_RNN}_params_CDDM.json"), "rb+"))
LCI_config_file = json.load(open(os.path.join("../", "data", "configs", f"LCI_config_{tag}.json"), mode="r", encoding='utf-8'))
task_data = rnn_config["task_params"]
tmp = task_data["coherences"][-1] * np.logspace(-(5 - 1), 0, 5, base=2)
coherences = np.concatenate([-np.array(tmp[::-1]), np.array([0]), np.array(tmp)]).tolist()
task_data["coherences"] = deepcopy(coherences)

# %%
# defining RNN:
activation_name = rnn_config["activation"]
RNN_N = rnn_config["N"]

if activation_name == 'relu':
    activation_RNN = lambda x: torch.maximum(x, torch.tensor(0))
elif activation_name == 'tanh':
    activation_RNN = torch.tanh
elif activation_name == 'sigmoid':
    activation_RNN = lambda x: 1/(1 + torch.exp(-x))
elif activation_name == 'softplus':
    activation_RNN = lambda x: torch.log(1 + torch.exp(5 * x))
dt = rnn_config["dt"]
tau = rnn_config["tau"]
connectivity_density_rec = rnn_config["connectivity_density_rec"]
spectral_rad = rnn_config["sr"]
sigma_inp = rnn_config["sigma_inp"]
sigma_rec = rnn_config["sigma_rec"]
seed = np.random.randint(1000000)
print(f"seed: {seed}")
if torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')
rng = torch.Generator(device=torch.device(device))
if not seed is None:
    rng.manual_seed(seed)
input_size = np.array(rnn_data["W_inp"]).shape[1]
output_size = np.array(rnn_data["W_out"]).shape[0]

# Task:
n_steps = task_data["n_steps"]

# LC
n = LCI_config_file["n"]
LC_N = LCI_config_file["N"]
w_inp = np.random.rand(8, 6) ######! removing constraints!
w_out = np.array(LCI_config_file["W_out"])

# Fitter:
lambda_w = 0.2
max_iter = LCI_config_file["max_iter"]
tol = LCI_config_file["tol"]
lr = LCI_config_file["lr"]
actvation_name = LCI_config_file["activation"]
inp_connectivity_mask = np.ones((8, 6)) ######! removing constraints!
rec_connectivity_mask = np.array(LCI_config_file["rec_connectivity_mask"])
out_connectivity_mask = np.array(LCI_config_file["out_connectivity_mask"])
Qinitialization = LCI_config_file["Qinitialization"]

if activation_name == 'relu':
    activation_LC = lambda x: torch.maximum(x, torch.tensor(0))
elif activation_name == 'tanh':
    activation_LC = torch.tanh
elif activation_name == 'sigmoid':
    activation_LC = lambda x: 1/(1 + torch.exp(-x))
elif activation_name == 'softplus':
    activation_LC = lambda x: torch.log(1 + torch.exp(5 * x))
# Out:
# seed: 520316

# %%
lambda_w
# Out:
# 0.08

# %%
# # creating instances:
rnn_torch = RNN_torch(N=RNN_N, dt=dt, tau=tau, input_size=input_size, output_size=output_size,
                      activation=activation_RNN, random_generator=rng, device=device,
                      sigma_rec=sigma_rec, sigma_inp=sigma_inp)
RNN_params = {"W_inp": np.array(rnn_data["W_inp"]),
              "W_rec": np.array(rnn_data["W_rec"]),
              "W_out": np.array(rnn_data["W_out"]),
              "b_rec": np.array(rnn_data["bias_rec"]),
              "y_init": np.zeros(RNN_N)}
rnn_torch.set_params(RNN_params)
task = TaskCDDM(n_steps=n_steps, n_inputs=input_size, n_outputs=output_size, task_params=task_data)

lc = LatentCircuit(n=n,
                   N=LC_N,
                   W_inp=torch.Tensor(w_inp).to(device),
                   W_out=torch.Tensor(w_out).to(device),
                   inp_connectivity_mask=torch.Tensor(inp_connectivity_mask).to(device),
                   rec_connectivity_mask=torch.Tensor(rec_connectivity_mask).to(device),
                   out_connectivity_mask=torch.Tensor(out_connectivity_mask).to(device),
                   activation=activation_LC,
                   sigma_rec=sigma_rec,
                   sigma_inp=sigma_inp,
                   device=device,
                   random_generator=rng)
criterion = torch.nn.MSELoss()

# optimizer = torch.optim.Adam(lc.parameters(), lr=lr)
optimizer = RiemannianAdam(lc.parameters(), lr=lr)

fitter = LatentCircuitFitter(LatentCircuit=lc, RNN=rnn_torch, Task=task,
                             max_iter=max_iter, tol=tol,
                             optimizer=optimizer, criterion=criterion,
                             lambda_w=lambda_w,
                             Qinitialization=Qinitialization)
# Out:
# Using cpu for RNN!
# Using cpu for Latent Circuit!

# %%
lc_inferred, train_losses, val_losses, net_params = fitter.run_training()
# Out:
# setting projection of RNN traces on the lower subspace
# iteration 0, train loss: 9.325421, validation loss: 1.016708
# iteration 1, train loss: 4.353261, validation loss: 0.679229
# iteration 2, train loss: 2.850063, validation loss: 0.540745
# iteration 3, train loss: 2.266166, validation loss: 0.481359
# iteration 4, train loss: 2.03912, validation loss: 0.456738
# iteration 5, train loss: 1.956686, validation loss: 0.446362
# iteration 6, train loss: 1.933806, validation loss: 0.441723
# iteration 7, train loss: 1.925725, validation loss: 0.438884
# iteration 8, train loss: 1.916803, validation loss: 0.436247
# iteration 9, train loss: 1.909003, validation loss: 0.4337
# iteration 10, train loss: 1.896002, validation loss: 0.43129
# iteration 11, train loss: 1.878945, validation loss: 0.429526
# iteration 12, train loss: 1.870005, validation loss: 0.428586
# iteration 13, train loss: 1.858486, validation loss: 0.428015
# iteration 14, train loss: 1.846487, validation loss: 0.427088
# iteration 15, train loss: 1.833148, validation loss: 0.425757
# iteration 16, train loss: 1.820394, validation loss: 0.424076
# iteration 17, train loss: 1.80639, validation loss: 0.421989
# iteration 18, train loss: 1.793114, validation loss: 0.419367
# iteration 19, train loss: 1.772483, validation loss: 0.416081
# iteration 20, train loss: 1.753979, validation loss: 0.412197
# iteration 21, train loss: 1.734053, validation loss: 0.407629
# iteration 22, train loss: 1.710291, validation loss: 0.402413
# iteration 23, train loss: 1.685375, validation loss: 0.396691
# iteration 24, train loss: 1.660675, validation loss: 0.390604
# iteration 25, train loss: 1.633439, validation loss: 0.384296
# iteration 26, train loss: 1.608606, validation loss: 0.377913
# iteration 27, train loss: 1.58177, validation loss: 0.371594
# iteration 28, train loss: 1.554764, validation loss: 0.365427
# iteration 29, train loss: 1.530066, validation loss: 0.359515
# iteration 30, train loss: 1.504916, validation loss: 0.353956
# iteration 31, train loss: 1.485432, validation loss: 0.34881
# iteration 32, train loss: 1.464033, validation loss: 0.344095
# iteration 33, train loss: 1.447424, validation loss: 0.339789
# iteration 34, train loss: 1.43175, validation loss: 0.335854
# iteration 35, train loss: 1.415403, validation loss: 0.33224
# iteration 36, train loss: 1.404754, validation loss: 0.32891
# iteration 37, train loss: 1.392659, validation loss: 0.325836
# iteration 38, train loss: 1.380308, validation loss: 0.323003
# iteration 39, train loss: 1.36971, validation loss: 0.320394
# iteration 40, train loss: 1.359703, validation loss: 0.317946
# iteration 41, train loss: 1.348436, validation loss: 0.315496
# iteration 42, train loss: 1.341004, validation loss: 0.312863
# iteration 43, train loss: 1.3336, validation loss: 0.31022
# iteration 44, train loss: 1.323935, validation loss: 0.30771
# iteration 45, train loss: 1.31919, validation loss: 0.305442
# iteration 46, train loss: 1.309046, validation loss: 0.30344
# iteration 47, train loss: 1.303477, validation loss: 0.301693
# iteration 48, train loss: 1.295022, validation loss: 0.300154
# iteration 49, train loss: 1.291932, validation loss: 0.298751
# iteration 50, train loss: 1.282307, validation loss: 0.297395
# iteration 51, train loss: 1.278977, validation loss: 0.295995
# iteration 52, train loss: 1.273481, validation loss: 0.294492
# iteration 53, train loss: 1.266657, validation loss: 0.292859
# iteration 54, train loss: 1.262516, validation loss: 0.291109
# iteration 55, train loss: 1.252995, validation loss: 0.289283
# iteration 56, train loss: 1.247456, validation loss: 0.287441
# iteration 57, train loss: 1.239601, validation loss: 0.285646
# iteration 58, train loss: 1.231489, validation loss: 0.283972
# iteration 59, train loss: 1.224812, validation loss: 0.282437
# iteration 60, train loss: 1.220279, validation loss: 0.281045
# iteration 61, train loss: 1.215849, validation loss: 0.279774
# iteration 62, train loss: 1.209918, validation loss: 0.278595
# iteration 63, train loss: 1.20824, validation loss: 0.277481
# iteration 64, train loss: 1.204164, validation loss: 0.276402
# iteration 65, train loss: 1.198935, validation loss: 0.275342
# iteration 66, train loss: 1.191553, validation loss: 0.274288
# iteration 67, train loss: 1.193418, validation loss: 0.273239
# iteration 68, train loss: 1.187165, validation loss: 0.272195
# iteration 69, train loss: 1.182326, validation loss: 0.271167
# iteration 70, train loss: 1.179606, validation loss: 0.270154
# iteration 71, train loss: 1.17557, validation loss: 0.269165
# iteration 72, train loss: 1.172257, validation loss: 0.2682
# iteration 73, train loss: 1.167093, validation loss: 0.267254
# iteration 74, train loss: 1.165529, validation loss: 0.266321
# iteration 75, train loss: 1.161741, validation loss: 0.265393
# iteration 76, train loss: 1.159888, validation loss: 0.264463
# iteration 77, train loss: 1.150477, validation loss: 0.263522
# iteration 78, train loss: 1.148712, validation loss: 0.262571
# iteration 79, train loss: 1.15017, validation loss: 0.261613
# iteration 80, train loss: 1.146543, validation loss: 0.26065
# iteration 81, train loss: 1.142392, validation loss: 0.259693
# iteration 82, train loss: 1.136394, validation loss: 0.258746
# iteration 83, train loss: 1.135173, validation loss: 0.257813
# iteration 84, train loss: 1.132789, validation loss: 0.256896
# iteration 85, train loss: 1.128881, validation loss: 0.255996
# iteration 86, train loss: 1.127681, validation loss: 0.255107
# iteration 87, train loss: 1.122102, validation loss: 0.254217
# iteration 88, train loss: 1.121339, validation loss: 0.253322
# iteration 89, train loss: 1.114231, validation loss: 0.252423
# iteration 90, train loss: 1.116641, validation loss: 0.251522
# iteration 91, train loss: 1.110507, validation loss: 0.250622
# iteration 92, train loss: 1.108799, validation loss: 0.24973
# iteration 93, train loss: 1.108183, validation loss: 0.248846
# iteration 94, train loss: 1.105277, validation loss: 0.247972
# iteration 95, train loss: 1.100952, validation loss: 0.247113
# iteration 96, train loss: 1.094895, validation loss: 0.246267
# iteration 97, train loss: 1.094977, validation loss: 0.245437
# iteration 98, train loss: 1.090018, validation loss: 0.244621
# iteration 99, train loss: 1.088319, validation loss: 0.243818
# iteration 100, train loss: 1.080921, validation loss: 0.243029
# iteration 101, train loss: 1.084638, validation loss: 0.242255
# iteration 102, train loss: 1.082487, validation loss: 0.241497
# iteration 103, train loss: 1.074925, validation loss: 0.240757
# iteration 104, train loss: 1.075878, validation loss: 0.240035
# iteration 105, train loss: 1.074891, validation loss: 0.239333
# iteration 106, train loss: 1.071561, validation loss: 0.23865
# iteration 107, train loss: 1.064623, validation loss: 0.237982
# iteration 108, train loss: 1.066004, validation loss: 0.237329
# iteration 109, train loss: 1.059674, validation loss: 0.236691
# iteration 110, train loss: 1.057035, validation loss: 0.236067
# iteration 111, train loss: 1.057636, validation loss: 0.235456
# iteration 112, train loss: 1.056822, validation loss: 0.234857
# iteration 113, train loss: 1.049995, validation loss: 0.234268
# iteration 114, train loss: 1.046013, validation loss: 0.233685
# iteration 115, train loss: 1.045596, validation loss: 0.23311
# iteration 116, train loss: 1.048891, validation loss: 0.232542
# iteration 117, train loss: 1.040385, validation loss: 0.231983
# iteration 118, train loss: 1.042321, validation loss: 0.23143
# iteration 119, train loss: 1.033351, validation loss: 0.230889
# iteration 120, train loss: 1.041065, validation loss: 0.230368
# iteration 121, train loss: 1.03466, validation loss: 0.229866
# iteration 122, train loss: 1.035378, validation loss: 0.229367
# iteration 123, train loss: 1.030189, validation loss: 0.228867
# iteration 124, train loss: 1.028517, validation loss: 0.228363
# iteration 125, train loss: 1.030683, validation loss: 0.227856
# iteration 126, train loss: 1.019902, validation loss: 0.227332
# iteration 127, train loss: 1.022174, validation loss: 0.226794
# iteration 128, train loss: 1.020977, validation loss: 0.226259
# iteration 129, train loss: 1.016792, validation loss: 0.225743
# iteration 130, train loss: 1.015541, validation loss: 0.225234
# iteration 131, train loss: 1.013983, validation loss: 0.224731
# iteration 132, train loss: 1.011689, validation loss: 0.224231
# iteration 133, train loss: 1.007875, validation loss: 0.223689
# iteration 134, train loss: 1.009094, validation loss: 0.223118
# iteration 135, train loss: 1.006148, validation loss: 0.222526
# iteration 136, train loss: 1.001184, validation loss: 0.221898
# iteration 137, train loss: 1.000032, validation loss: 0.221224
# iteration 138, train loss: 0.991466, validation loss: 0.220499
# iteration 139, train loss: 0.998043, validation loss: 0.219748
# iteration 140, train loss: 0.990896, validation loss: 0.219013
# iteration 141, train loss: 0.990835, validation loss: 0.21838
# iteration 142, train loss: 0.982597, validation loss: 0.217503
# iteration 143, train loss: 0.976668, validation loss: 0.216304
# iteration 144, train loss: 0.969514, validation loss: 0.214859
# iteration 145, train loss: 0.970317, validation loss: 0.213081
# iteration 146, train loss: 0.964874, validation loss: 0.211198
# iteration 147, train loss: 0.957453, validation loss: 0.209122
# iteration 148, train loss: 0.949442, validation loss: 0.206448
# iteration 149, train loss: 0.942443, validation loss: 0.202947
# iteration 150, train loss: 0.926822, validation loss: 0.197989
# iteration 151, train loss: 0.900588, validation loss: 0.211735
# iteration 152, train loss: 0.917696, validation loss: 0.234237
# iteration 153, train loss: 1.041466, validation loss: 0.216865
# iteration 154, train loss: 0.917919, validation loss: 0.186495
# iteration 155, train loss: 0.825355, validation loss: 0.181084
# iteration 156, train loss: 0.839463, validation loss: 0.232201
# iteration 157, train loss: 0.963218, validation loss: 0.187053
# iteration 158, train loss: 0.798964, validation loss: 0.219922
# iteration 159, train loss: 1.019565, validation loss: 0.174359
# iteration 160, train loss: 0.850732, validation loss: 0.264086
# iteration 161, train loss: 1.077159, validation loss: 0.280209
# iteration 162, train loss: 1.153332, validation loss: 0.238214
# iteration 163, train loss: 1.010906, validation loss: 0.198032
# iteration 164, train loss: 0.859853, validation loss: 0.196634
# iteration 165, train loss: 0.910431, validation loss: 0.210229
# iteration 166, train loss: 0.999707, validation loss: 0.202705
# iteration 167, train loss: 0.930643, validation loss: 0.195945
# iteration 168, train loss: 0.883239, validation loss: 0.200654
# iteration 169, train loss: 0.896527, validation loss: 0.20863
# iteration 170, train loss: 0.926678, validation loss: 0.211051
# iteration 171, train loss: 0.942288, validation loss: 0.205685
# iteration 172, train loss: 0.918304, validation loss: 0.196848
# iteration 173, train loss: 0.884679, validation loss: 0.191737
# iteration 174, train loss: 0.869391, validation loss: 0.192477
# iteration 175, train loss: 0.870581, validation loss: 0.194421
# iteration 176, train loss: 0.882939, validation loss: 0.190644
# iteration 177, train loss: 0.869221, validation loss: 0.183372
# iteration 178, train loss: 0.834491, validation loss: 0.182091
# iteration 179, train loss: 0.812927, validation loss: 0.186681
# iteration 180, train loss: 0.818074, validation loss: 0.184286
# iteration 181, train loss: 0.810044, validation loss: 0.171439
# iteration 182, train loss: 0.743728, validation loss: 0.162419
# iteration 183, train loss: 0.809128, validation loss: 0.172492
# iteration 184, train loss: 0.701828, validation loss: 0.187738
# iteration 185, train loss: 0.717033, validation loss: 0.154062
# iteration 186, train loss: 0.729317, validation loss: 0.230415
# iteration 187, train loss: 0.842631, validation loss: 0.200469
# iteration 188, train loss: 0.724072, validation loss: 0.214472
# iteration 189, train loss: 1.125691, validation loss: 0.266115
# iteration 190, train loss: 1.233132, validation loss: 0.239777
# iteration 191, train loss: 1.097597, validation loss: 0.175511
# iteration 192, train loss: 0.865545, validation loss: 0.202043
# iteration 193, train loss: 0.841884, validation loss: 0.24586
# iteration 194, train loss: 1.02184, validation loss: 0.22348
# iteration 195, train loss: 0.950249, validation loss: 0.187198
# iteration 196, train loss: 0.839622, validation loss: 0.179101
# iteration 197, train loss: 0.83183, validation loss: 0.190126
# iteration 198, train loss: 0.891899, validation loss: 0.198385
# iteration 199, train loss: 0.922281, validation loss: 0.193727
# iteration 200, train loss: 0.898804, validation loss: 0.180559
# iteration 201, train loss: 0.831358, validation loss: 0.173722
# iteration 202, train loss: 0.789607, validation loss: 0.179974
# iteration 203, train loss: 0.79793, validation loss: 0.187912
# iteration 204, train loss: 0.817668, validation loss: 0.182416
# iteration 205, train loss: 0.795043, validation loss: 0.16542
# iteration 206, train loss: 0.741439, validation loss: 0.156351
# iteration 207, train loss: 0.718788, validation loss: 0.15863
# iteration 208, train loss: 0.764573, validation loss: 0.152501
# iteration 209, train loss: 0.730834, validation loss: 0.151504
# iteration 210, train loss: 0.68676, validation loss: 0.176623
# iteration 211, train loss: 0.711679, validation loss: 0.16176
# iteration 212, train loss: 0.660548, validation loss: 0.134648
# iteration 213, train loss: 0.686099, validation loss: 0.13239
# iteration 214, train loss: 0.61325, validation loss: 0.200191
# iteration 215, train loss: 0.711628, validation loss: 0.158912
# iteration 216, train loss: 0.565953, validation loss: 0.124522
# iteration 217, train loss: 0.712331, validation loss: 0.192157
# iteration 218, train loss: 0.662528, validation loss: 0.168211
# iteration 219, train loss: 0.589769, validation loss: 0.117092
# iteration 220, train loss: 0.636099, validation loss: 0.132018
# iteration 221, train loss: 0.545847, validation loss: 0.169518
# iteration 222, train loss: 0.614997, validation loss: 0.116871
# iteration 223, train loss: 0.542552, validation loss: 0.112416
# iteration 224, train loss: 0.571245, validation loss: 0.152
# iteration 225, train loss: 0.566868, validation loss: 0.132456
# iteration 226, train loss: 0.530476, validation loss: 0.108558
# iteration 227, train loss: 0.598753, validation loss: 0.142217
# iteration 228, train loss: 0.509947, validation loss: 0.120922
# iteration 229, train loss: 0.476507, validation loss: 0.109029
# iteration 230, train loss: 0.480451, validation loss: 0.174221
# iteration 231, train loss: 0.556094, validation loss: 0.123243
# iteration 232, train loss: 0.432637, validation loss: 0.101644
# iteration 233, train loss: 0.523686, validation loss: 0.192651
# iteration 234, train loss: 0.657522, validation loss: 0.164561
# iteration 235, train loss: 0.501136, validation loss: 0.09179
# iteration 236, train loss: 0.576836, validation loss: 0.16907
# iteration 237, train loss: 0.592663, validation loss: 0.13643
# iteration 238, train loss: 0.459799, validation loss: 0.146718
# iteration 239, train loss: 0.536222, validation loss: 0.13049
# iteration 240, train loss: 0.540819, validation loss: 0.085155
# iteration 241, train loss: 0.441808, validation loss: 0.137116
# iteration 242, train loss: 0.480398, validation loss: 0.115759
# iteration 243, train loss: 0.470373, validation loss: 0.141985
# iteration 244, train loss: 0.522207, validation loss: 0.099745
# iteration 245, train loss: 0.479468, validation loss: 0.137997
# iteration 246, train loss: 0.427553, validation loss: 0.104626
# iteration 247, train loss: 0.399276, validation loss: 0.081626
# iteration 248, train loss: 0.50007, validation loss: 0.166415
# iteration 249, train loss: 0.503438, validation loss: 0.156711
# iteration 250, train loss: 0.469155, validation loss: 0.08591
# iteration 251, train loss: 0.454644, validation loss: 0.184001
# iteration 252, train loss: 0.526116, validation loss: 0.117235
# iteration 253, train loss: 0.420259, validation loss: 0.125088
# iteration 254, train loss: 0.526835, validation loss: 0.148464
# iteration 255, train loss: 0.419562, validation loss: 0.122033
# iteration 256, train loss: 0.4012, validation loss: 0.108902
# iteration 257, train loss: 0.498688, validation loss: 0.181354
# iteration 258, train loss: 0.575146, validation loss: 0.115594
# iteration 259, train loss: 0.360139, validation loss: 0.112388
# iteration 260, train loss: 0.45351, validation loss: 0.166638
# iteration 261, train loss: 0.469941, validation loss: 0.105945
# iteration 262, train loss: 0.414767, validation loss: 0.131955
# iteration 263, train loss: 0.441115, validation loss: 0.120968
# iteration 264, train loss: 0.372583, validation loss: 0.145038
# iteration 265, train loss: 0.422138, validation loss: 0.129226
# iteration 266, train loss: 0.435674, validation loss: 0.117593
# iteration 267, train loss: 0.378381, validation loss: 0.173639
# iteration 268, train loss: 0.549947, validation loss: 0.144519
# iteration 269, train loss: 0.474891, validation loss: 0.092614
# iteration 270, train loss: 0.506212, validation loss: 0.19809
# iteration 271, train loss: 0.525444, validation loss: 0.178693
# iteration 272, train loss: 0.531983, validation loss: 0.147956
# iteration 273, train loss: 0.568731, validation loss: 0.162843
# iteration 274, train loss: 0.56765, validation loss: 0.151875
# iteration 275, train loss: 0.442861, validation loss: 0.193976
# iteration 276, train loss: 0.541427, validation loss: 0.14185
# iteration 277, train loss: 0.525823, validation loss: 0.115088
# iteration 278, train loss: 0.436052, validation loss: 0.164939
# iteration 279, train loss: 0.490668, validation loss: 0.157101
# iteration 280, train loss: 0.466635, validation loss: 0.131789
# iteration 281, train loss: 0.436799, validation loss: 0.148173
# iteration 282, train loss: 0.470989, validation loss: 0.146501
# iteration 283, train loss: 0.408236, validation loss: 0.134858
# iteration 284, train loss: 0.425136, validation loss: 0.165235
# iteration 285, train loss: 0.484159, validation loss: 0.136176
# iteration 286, train loss: 0.430988, validation loss: 0.103815
# iteration 287, train loss: 0.484482, validation loss: 0.142238
# iteration 288, train loss: 0.45843, validation loss: 0.12623
# iteration 289, train loss: 0.396562, validation loss: 0.115082
# iteration 290, train loss: 0.44976, validation loss: 0.100076
# iteration 291, train loss: 0.431887, validation loss: 0.165871
# iteration 292, train loss: 0.449977, validation loss: 0.140677
# iteration 293, train loss: 0.436642, validation loss: 0.109804
# iteration 294, train loss: 0.473737, validation loss: 0.124975
# iteration 295, train loss: 0.454664, validation loss: 0.163574
# iteration 296, train loss: 0.475095, validation loss: 0.143279
# iteration 297, train loss: 0.393408, validation loss: 0.113618
# iteration 298, train loss: 0.415799, validation loss: 0.148275
# iteration 299, train loss: 0.419187, validation loss: 0.161212
# iteration 300, train loss: 0.432094, validation loss: 0.105025
# iteration 301, train loss: 0.433137, validation loss: 0.111958
# iteration 302, train loss: 0.452716, validation loss: 0.160414
# iteration 303, train loss: 0.473512, validation loss: 0.157047
# iteration 304, train loss: 0.457152, validation loss: 0.110086
# iteration 305, train loss: 0.383421, validation loss: 0.101192
# iteration 306, train loss: 0.47887, validation loss: 0.156762
# iteration 307, train loss: 0.452954, validation loss: 0.163845
# iteration 308, train loss: 0.49589, validation loss: 0.11449
# iteration 309, train loss: 0.393043, validation loss: 0.133132
# iteration 310, train loss: 0.550739, validation loss: 0.118531
# iteration 311, train loss: 0.386032, validation loss: 0.191294
# iteration 312, train loss: 0.558179, validation loss: 0.178146
# iteration 313, train loss: 0.540244, validation loss: 0.114641
# iteration 314, train loss: 0.378488, validation loss: 0.163318
# iteration 315, train loss: 0.555339, validation loss: 0.140582
# iteration 316, train loss: 0.474885, validation loss: 0.137289
# iteration 317, train loss: 0.404686, validation loss: 0.16229
# iteration 318, train loss: 0.49943, validation loss: 0.123282
# iteration 319, train loss: 0.430141, validation loss: 0.133841
# iteration 320, train loss: 0.426978, validation loss: 0.153257
# iteration 321, train loss: 0.44212, validation loss: 0.123842
# iteration 322, train loss: 0.402351, validation loss: 0.157667
# iteration 323, train loss: 0.443417, validation loss: 0.160263
# iteration 324, train loss: 0.455039, validation loss: 0.129904
# iteration 325, train loss: 0.370526, validation loss: 0.141313
# iteration 326, train loss: 0.492221, validation loss: 0.135732
# iteration 327, train loss: 0.412916, validation loss: 0.145744
# iteration 328, train loss: 0.413712, validation loss: 0.169999
# iteration 329, train loss: 0.425875, validation loss: 0.1652
# iteration 330, train loss: 0.463793, validation loss: 0.118634
# iteration 331, train loss: 0.416309, validation loss: 0.089738
# iteration 332, train loss: 0.518691, validation loss: 0.120538
# iteration 333, train loss: 0.38218, validation loss: 0.164795
# iteration 334, train loss: 0.499634, validation loss: 0.151835
# iteration 335, train loss: 0.443844, validation loss: 0.108039
# iteration 336, train loss: 0.40492, validation loss: 0.080371
# iteration 337, train loss: 0.447684, validation loss: 0.109868
# iteration 338, train loss: 0.385202, validation loss: 0.14744
# iteration 339, train loss: 0.441269, validation loss: 0.167738
# iteration 340, train loss: 0.492339, validation loss: 0.111501
# iteration 341, train loss: 0.382119, validation loss: 0.082236
# iteration 342, train loss: 0.421864, validation loss: 0.112573
# iteration 343, train loss: 0.391198, validation loss: 0.157105
# iteration 344, train loss: 0.496184, validation loss: 0.157147
# iteration 345, train loss: 0.435561, validation loss: 0.129644
# iteration 346, train loss: 0.54864, validation loss: 0.165118
# iteration 347, train loss: 0.469963, validation loss: 0.15112
# iteration 348, train loss: 0.437374, validation loss: 0.132021
# iteration 349, train loss: 0.483569, validation loss: 0.189766
# iteration 350, train loss: 0.561761, validation loss: 0.155588
# iteration 351, train loss: 0.437346, validation loss: 0.161513
# iteration 352, train loss: 0.453402, validation loss: 0.103873
# iteration 353, train loss: 0.483373, validation loss: 0.128069
# iteration 354, train loss: 0.415296, validation loss: 0.163609
# iteration 355, train loss: 0.428425, validation loss: 0.133621
# iteration 356, train loss: 0.375911, validation loss: 0.096097
# iteration 357, train loss: 0.423173, validation loss: 0.086288
# iteration 358, train loss: 0.438159, validation loss: 0.127264
# iteration 359, train loss: 0.353971, validation loss: 0.1437
# iteration 360, train loss: 0.400111, validation loss: 0.107823
# iteration 361, train loss: 0.368839, validation loss: 0.105455
# iteration 362, train loss: 0.419627, validation loss: 0.129191
# iteration 363, train loss: 0.350216, validation loss: 0.146789
# iteration 364, train loss: 0.413623, validation loss: 0.112285
# iteration 365, train loss: 0.356624, validation loss: 0.106854
# iteration 366, train loss: 0.401736, validation loss: 0.139919
# iteration 367, train loss: 0.371599, validation loss: 0.147207
# iteration 368, train loss: 0.421171, validation loss: 0.118639
# iteration 369, train loss: 0.375578, validation loss: 0.12598
# iteration 370, train loss: 0.408857, validation loss: 0.143587
# iteration 371, train loss: 0.383631, validation loss: 0.146373
# iteration 372, train loss: 0.413774, validation loss: 0.131023
# iteration 373, train loss: 0.401758, validation loss: 0.098125
# iteration 374, train loss: 0.476797, validation loss: 0.126749
# iteration 375, train loss: 0.374243, validation loss: 0.154526
# iteration 376, train loss: 0.476538, validation loss: 0.1646
# iteration 377, train loss: 0.470788, validation loss: 0.111855
# iteration 378, train loss: 0.428311, validation loss: 0.156779
# iteration 379, train loss: 0.451974, validation loss: 0.140807
# iteration 380, train loss: 0.381704, validation loss: 0.148088
# iteration 381, train loss: 0.48132, validation loss: 0.159279
# iteration 382, train loss: 0.488037, validation loss: 0.148364
# iteration 383, train loss: 0.435189, validation loss: 0.113444
# iteration 384, train loss: 0.432791, validation loss: 0.084065
# iteration 385, train loss: 0.406738, validation loss: 0.141481
# iteration 386, train loss: 0.426116, validation loss: 0.144668
# iteration 387, train loss: 0.442998, validation loss: 0.126146
# iteration 388, train loss: 0.394903, validation loss: 0.085044
# iteration 389, train loss: 0.45375, validation loss: 0.097932
# iteration 390, train loss: 0.374527, validation loss: 0.127842
# iteration 391, train loss: 0.39785, validation loss: 0.125905
# iteration 392, train loss: 0.377789, validation loss: 0.094272
# iteration 393, train loss: 0.37278, validation loss: 0.094217
# iteration 394, train loss: 0.413067, validation loss: 0.136023
# iteration 395, train loss: 0.371965, validation loss: 0.145275
# iteration 396, train loss: 0.396779, validation loss: 0.112031
# iteration 397, train loss: 0.36846, validation loss: 0.124586
# iteration 398, train loss: 0.420206, validation loss: 0.105611
# iteration 399, train loss: 0.393318, validation loss: 0.131455
# iteration 400, train loss: 0.372224, validation loss: 0.129086
# iteration 401, train loss: 0.382157, validation loss: 0.106585
# iteration 402, train loss: 0.345863, validation loss: 0.10711
# iteration 403, train loss: 0.350426, validation loss: 0.116808
# iteration 404, train loss: 0.364079, validation loss: 0.12349
# iteration 405, train loss: 0.352766, validation loss: 0.109735
# iteration 406, train loss: 0.363901, validation loss: 0.108414
# iteration 407, train loss: 0.36837, validation loss: 0.135997
# iteration 408, train loss: 0.354394, validation loss: 0.114712
# iteration 409, train loss: 0.355391, validation loss: 0.087416
# iteration 410, train loss: 0.390645, validation loss: 0.144518
# iteration 411, train loss: 0.415732, validation loss: 0.130075
# iteration 412, train loss: 0.347258, validation loss: 0.115553
# iteration 413, train loss: 0.380444, validation loss: 0.106486
# iteration 414, train loss: 0.358153, validation loss: 0.121128
# iteration 415, train loss: 0.401071, validation loss: 0.129169
# iteration 416, train loss: 0.410328, validation loss: 0.115642
# iteration 417, train loss: 0.366389, validation loss: 0.094605
# iteration 418, train loss: 0.416064, validation loss: 0.118319
# iteration 419, train loss: 0.403636, validation loss: 0.164679
# iteration 420, train loss: 0.485414, validation loss: 0.131905
# iteration 421, train loss: 0.440696, validation loss: 0.102909
# iteration 422, train loss: 0.414363, validation loss: 0.123802
# iteration 423, train loss: 0.414016, validation loss: 0.115384
# iteration 424, train loss: 0.365478, validation loss: 0.133277
# iteration 425, train loss: 0.418158, validation loss: 0.116357
# iteration 426, train loss: 0.382483, validation loss: 0.109259
# iteration 427, train loss: 0.397593, validation loss: 0.097923
# iteration 428, train loss: 0.362629, validation loss: 0.120961
# iteration 429, train loss: 0.361258, validation loss: 0.142068
# iteration 430, train loss: 0.412022, validation loss: 0.110214
# iteration 431, train loss: 0.334071, validation loss: 0.075924
# iteration 432, train loss: 0.415403, validation loss: 0.110465
# iteration 433, train loss: 0.37498, validation loss: 0.125388
# iteration 434, train loss: 0.388319, validation loss: 0.094193
# iteration 435, train loss: 0.330963, validation loss: 0.095242
# iteration 436, train loss: 0.366816, validation loss: 0.102442
# iteration 437, train loss: 0.33216, validation loss: 0.09251
# iteration 438, train loss: 0.386385, validation loss: 0.121895
# iteration 439, train loss: 0.398892, validation loss: 0.118241
# iteration 440, train loss: 0.367204, validation loss: 0.095759
# iteration 441, train loss: 0.370119, validation loss: 0.119624
# iteration 442, train loss: 0.404091, validation loss: 0.105119
# iteration 443, train loss: 0.338872, validation loss: 0.096539
# iteration 444, train loss: 0.371378, validation loss: 0.11933
# iteration 445, train loss: 0.377313, validation loss: 0.116314
# iteration 446, train loss: 0.3348, validation loss: 0.115069
# iteration 447, train loss: 0.356479, validation loss: 0.113691
# iteration 448, train loss: 0.360789, validation loss: 0.098431
# iteration 449, train loss: 0.349601, validation loss: 0.107459
# iteration 450, train loss: 0.337281, validation loss: 0.124462
# iteration 451, train loss: 0.331458, validation loss: 0.136445
# iteration 452, train loss: 0.373626, validation loss: 0.088456
# iteration 453, train loss: 0.43741, validation loss: 0.090642
# iteration 454, train loss: 0.380986, validation loss: 0.137953
# iteration 455, train loss: 0.353799, validation loss: 0.133995
# iteration 456, train loss: 0.398038, validation loss: 0.095901
# iteration 457, train loss: 0.357251, validation loss: 0.119581
# iteration 458, train loss: 0.373561, validation loss: 0.107321
# iteration 459, train loss: 0.329164, validation loss: 0.102269
# iteration 460, train loss: 0.4345, validation loss: 0.120745
# iteration 461, train loss: 0.37389, validation loss: 0.101979
# iteration 462, train loss: 0.336515, validation loss: 0.105139
# iteration 463, train loss: 0.38166, validation loss: 0.113858
# iteration 464, train loss: 0.347829, validation loss: 0.124806
# iteration 465, train loss: 0.366696, validation loss: 0.118471
# iteration 466, train loss: 0.378433, validation loss: 0.110303
# iteration 467, train loss: 0.376395, validation loss: 0.16905
# iteration 468, train loss: 0.474047, validation loss: 0.112975
# iteration 469, train loss: 0.338558, validation loss: 0.123396
# iteration 470, train loss: 0.468747, validation loss: 0.141394
# iteration 471, train loss: 0.409718, validation loss: 0.175406
# iteration 472, train loss: 0.504848, validation loss: 0.118735
# iteration 473, train loss: 0.404093, validation loss: 0.094401
# iteration 474, train loss: 0.575748, validation loss: 0.127099
# iteration 475, train loss: 0.405356, validation loss: 0.157597
# iteration 476, train loss: 0.479341, validation loss: 0.15586
# iteration 477, train loss: 0.484482, validation loss: 0.090758
# iteration 478, train loss: 0.398006, validation loss: 0.086183
# iteration 479, train loss: 0.52512, validation loss: 0.094868
# iteration 480, train loss: 0.380891, validation loss: 0.152797
# iteration 481, train loss: 0.465717, validation loss: 0.138905
# iteration 482, train loss: 0.4391, validation loss: 0.116322
# iteration 483, train loss: 0.424444, validation loss: 0.090145
# iteration 484, train loss: 0.442496, validation loss: 0.123419
# iteration 485, train loss: 0.442468, validation loss: 0.141436
# iteration 486, train loss: 0.43503, validation loss: 0.128463
# iteration 487, train loss: 0.381589, validation loss: 0.129974
# iteration 488, train loss: 0.428271, validation loss: 0.11277
# iteration 489, train loss: 0.373894, validation loss: 0.150902
# iteration 490, train loss: 0.447723, validation loss: 0.094328
# iteration 491, train loss: 0.425602, validation loss: 0.13524
# iteration 492, train loss: 0.412217, validation loss: 0.136748
# iteration 493, train loss: 0.406067, validation loss: 0.092826
# iteration 494, train loss: 0.398567, validation loss: 0.121052
# iteration 495, train loss: 0.378459, validation loss: 0.131439
# iteration 496, train loss: 0.3857, validation loss: 0.115001
# iteration 497, train loss: 0.362287, validation loss: 0.088254
# iteration 498, train loss: 0.354234, validation loss: 0.109455
# iteration 499, train loss: 0.358994, validation loss: 0.115928

# %%
n = LCI_config_file["n"]
U = net_params["U"]
q = net_params["q"]
Q = q.T @ U
W_rec = RNN_params["W_rec"]
w_rec_bar = Q @ W_rec @ Q.T
w_rec = net_params["W_rec"]
names = ["ctx m", "ctx c", "mr", "ml", "cr", "cl", "OutR", "OutL"]
w_rec = net_params["W_rec"]
w_inp = net_params["W_inp"]
w_out = net_params["W_out"]
dt = net_params["dt"]
tau = net_params["tau"]

activation_fun_circuit = lambda x: np.maximum(0, x)
circuit = RNN_numpy(N=n, W_rec=w_rec, W_inp=w_inp, W_out=w_out, dt=dt, tau=tau, activation=activation_fun_circuit)
circuit.y = np.zeros(n)

# defining RNN
N = rnn_data["N"]
x = np.random.randn(n)
W_rec = RNN_params["W_rec"]
W_inp = RNN_params["W_inp"]
W_out = RNN_params["W_out"]
dt = net_params["dt"]
tau = net_params["tau"]
activation_fun_RNN = lambda x: np.maximum(0, x)
RNN = RNN_numpy(N=N, W_rec=W_rec, W_inp=W_inp, W_out=W_out, dt=dt, tau=tau, activation=activation_fun_RNN)
RNN.y = np.zeros(n)

# defining analyzer
if tag == '8nodes':
    node_labels = ['ctx m', "ctx c", "mR", "mL", "cR", "cL", "OutR", "OutL"]
elif tag == '12nodes':
    node_labels = ['ctx m', "ctx c", "mR", "mL", "cR", "cL", "mRx", "mLx", "cRx", "cLx", "OutR", "OutL"]
analyzer = LCAnalyzer(circuit, labels=node_labels)
input_batch_valid, target_batch_valid, conditions_valid = task.get_batch()
mask = np.array(rnn_config["mask"])

#MSE mse_score_RNN
score_function = lambda x, y: np.mean((x - y) ** 2)
mse_score = analyzer.get_validation_score(scoring_function=mse_scoring,
                                          input_batch=input_batch_valid,
                                          target_batch=target_batch_valid,
                                          mask=mask,
                                          sigma_rec=sigma_rec,
                                          sigma_inp=sigma_inp)
mse_score = np.round(mse_score, 8)
print(f"MSE: {mse_score}")

# Total variance
batch_size = input_batch_valid.shape[2]
RNN.clear_history()
circuit.clear_history()
RNN_trajectories, RNN_output = RNN.run_multiple_trajectories(input_timeseries=input_batch_valid, sigma_rec=0, sigma_inp=0)
lc_trajectories, lc_output = circuit.run_multiple_trajectories(input_timeseries=input_batch_valid, sigma_rec=0, sigma_inp=0)
lc_trajectories_emb = np.swapaxes(Q.T @ np.swapaxes(lc_trajectories, 0, 1), 0, 1)
RNN_trajectories_proj = np.swapaxes(Q @ np.swapaxes(RNN_trajectories, 0, 1), 0, 1)
r2_tot = np.mean([R2(lc_trajectories_emb[:, mask, i], RNN_trajectories[:, mask, i]) for i in range(batch_size)])
r2_proj = np.mean([R2(lc_trajectories[:, mask, i], RNN_trajectories_proj[:, mask, i]) for i in range(batch_size)])
print(f"Total R2: {r2_tot}")
print(f"Projected R2: {r2_proj}")
scores = {"mse_score": mse_score, "r2_tot":r2_tot, "r2_proj" : r2_proj}
# Out:
# MSE: 0.03847581
# Total R2: 0.7571300438580907
# Projected R2: 0.8272107755581719

# %%
np.set_printoptions(suppress=True)
np.round(w_inp,3)
# Out:
# array([[ 0.045,  0.479,  0.038, -0.   , -0.   , -0.   ],
#        [ 0.003,  0.004,  0.   ,  0.001,  0.   ,  0.   ],
#        [ 0.804,  0.079, -0.   , -0.   , -0.   , -0.   ],
#        [ 1.368,  0.009,  0.321,  0.435,  0.861,  0.106],
#        [ 0.107,  0.319, -0.   , -0.   , -0.   , -0.   ],
#        [-0.   ,  0.369,  0.821, -0.   , -0.   ,  1.696],
#        [ 0.035,  0.32 ,  1.283,  0.274,  0.988,  0.529],
#        [ 0.462, -0.   ,  0.019,  1.024,  0.61 ,  0.257]], dtype=float32)

# %%
w_rec = net_params["W_rec"]
fig_w_rec = analyzer.plot_recurrent_matrix()
plt.show()

# %%
fig_w_rec_comparison = analyzer.plot_recurrent_matrix_comparison(w_rec_bar=w_rec_bar)
plt.show()

# %%
print(f"Plotting random trials")
inds = np.random.choice(np.arange(input_batch_valid.shape[-1]), 12)
inputs = input_batch_valid[..., inds]
targets = target_batch_valid[..., inds]
fig_trials = analyzer.plot_trials(inputs, targets, mask, sigma_rec=sigma_rec, sigma_inp=sigma_inp)
plt.show()
# Out:
# Plotting random trials

# %%
num_levels = len(task_data["coherences"])
analyzer.calc_psychometric_data(task, mask, num_levels=num_levels, num_repeats=31, sigma_rec=0.03, sigma_inp=0.03)
fig_psycho = analyzer.plot_psychometric_data()
plt.show()

# %%
print(f"Analyzing fixed points")
dsa = DynamicSystemAnalyzerCDDM(circuit)
params = {"fun_tol": 0.05,
          "diff_cutoff": 1e-4,
          "sigma_init_guess": 15,
          "patience": 50,
          "stop_length": 50,
          "mode": "approx"}
dsa.get_fixed_points(Input=np.array([1, 0, 0.5, 0.5, 0.5, 0.5]), **params)
dsa.get_fixed_points(Input=np.array([0, 1, 0.5, 0.5, 0.5, 0.5]), **params)
print(f"Calculating Line Attractor analytics")
dsa.calc_LineAttractor_analytics(N_points=101)
fig_LA3D = dsa.plot_LineAttractor_3D()
datasaver.save_figure(fig_LA3D, f"{r2_tot}_LC_LA3D.png")
datasaver.save_data(dsa.fp_data, f"{r2_tot}_fp_data.pkl")
datasaver.save_data(dsa.LA_data, f"{r2_tot}_LA_data.pkl")
if disp: plt.show()

LA_data_lc = dsa.fp_data
LA_data_RNN = pickle.load(open(os.path.join(RNN_folder_full_path, f"{mse_score_RNN}_LA_data.pkl"), "rb+"))
fig_selection_vects = analyzer.plot_selection_vectors(Q, LA_data_lc, LA_data_RNN)
plt.show()
