# %%
import numpy as np
from matplotlib import pyplot as plt
import os
import pickle
import json
from copy import deepcopy
import pandas as pd
import sys
sys.path.insert(0, '../')
sys.path.insert(0, '../../')
from style import style_setup

os.system('python ../style/style_setup.py')
# Out:
# 0

# %%
path_to_folders = '/Users/tolmach/Documents/GitHub/latent_circuit_inference/data/inferred_LCs/CDDMrelu'
path_to_RNNs = '/Users/tolmach/Documents/GitHub/rnn_coach/data/trained_RNNs/CDDMrelu'

# %%
subfolders = os.listdir(path_to_folders)
subfolders.remove(".DS_Store")

# %%
subfolders.remove("0.0117071_CDDM;relu;N=100;lmbdo=0.3;lmbdr=0.5;lr=0.002;maxiter=3000")

# %%
len(subfolders)
# Out:
# 110

# %% [markdown]
# # first check how well the inferred parameters correlated with one another!

# %%
def corr_series(A, width=5):
    res = []
    np.fill_diagonal(A, 0)
    for i in range(A.shape[0]-width):
        res.append(np.mean(A[i:i + width,i:i + width]))
    return np.array(res)

filtered_LC_folders = []
for sf in subfolders:
    path_to_subfolder = os.path.join(path_to_folders, sf)
    LC_folders = os.listdir(path_to_subfolder)
#     print(path_to_subfolder)
    if ".DS_Store" in LC_folders:
        LC_folders.remove(".DS_Store")
    # something wrong with this
    print(sf)
    scores1 = [float(LC_folder.split("_")[0]) for LC_folder in LC_folders]
    scores2 = [float(LC_folder.split("_")[1]) for LC_folder in LC_folders]
    pdf = pd.DataFrame({"R2 total" : scores1, "R2 projection" : scores2, "LC_folder_name" : LC_folders})
    pdf = pdf.sort_values(by=['R2 total'], ascending=False)
    folders_sorted = list(pdf["LC_folder_name"])
    scores1_sorted = list(pdf["R2 total"])
    scores2_sorted = list(pdf["R2 projection"])
    W_inps_sorted = []
    W_recs_sorted = []
    W_outs_sorted = []
    qs_sorted = []
    for i, folder in enumerate(folders_sorted):
        data_file = os.path.join(path_to_subfolder, folder, f"{scores1_sorted[i]}_{scores2_sorted[i]}_LC_params.json")
        data = json.load(open(data_file, "rb+"))
        W_inps_sorted.append(np.array(data["W_inp"]).flatten().reshape(1, -1))
        W_recs_sorted.append(np.array(data["W_rec"]).flatten().reshape(1, -1))
        W_outs_sorted.append(np.array(data["W_out"]).flatten().reshape(1, -1))
        qs_sorted.append(np.array(data["q"]).flatten().reshape(1, -1))
#         print(qs_sorted[-1].shape)
        W_inps_sorted[-1] /= np.linalg.norm(W_inps_sorted[-1])
        W_recs_sorted[-1] /= np.linalg.norm(W_recs_sorted[-1])
        W_outs_sorted[-1] /= np.linalg.norm(W_outs_sorted[-1])
        qs_sorted[-1] /= np.linalg.norm(qs_sorted[-1])
    W_inps_flat = np.vstack(W_inps_sorted)
    W_outs_flat = np.vstack(W_outs_sorted)
    W_recs_flat = np.vstack(W_recs_sorted)
    qs_flat = np.vstack(qs_sorted)
    
    #now plot a bunch of correlations!
    fig, axs = plt.subplots(1, 1, figsize = (4, 2))
    axs.plot(corr_series(qs_flat @ qs_flat.T), label = "q")
    res = corr_series(W_recs_flat @ W_recs_flat.T)
    if res[0]>0.65:
        filtered_LC_folders.append(sf)
    axs.plot(res, label = "W_rec")
    axs.set_ylim([0.3, 1])
    plt.grid(True)
    plt.legend()
    plt.show()
# Out:
# 0.0114539_CDDM;relu;N=99;lmbdo=0.3;lmbdr=0.5;lr=0.002;maxiter=3000
# [0
CDDM;relu;N=100;lmbdo=0.3;lmbdr=0.5;lr=0.002;maxiter=3000
# [0.74200348 0.73928038 0.74175522 0.75149608 0.75446977 0.75037078
#  0.74671759 0.74762491 0.74935349 0.75582813 0.75016112 0.74008943
#  0.71091889 0.70052296 0.68964081 0.67509112 0.6490038  0.62645742
#  0.61118944 0.61511907 0.56927339 0.5055611  0.49707522 0.49130607
#  0.51885255 0.42475254 0.4145762  0.47362393 0.40902975 0.37383215
#  0.46016183 0.48968806 0.47177459 0.41115718 0.37207191 0.33037973
#  0.2600518  0.26656355 0.25995449]
# 0.0107927_CDDM;relu;N=100;lmbdo=0.3;lmbdr=0.5;lr=0.002;maxiter=3000
# [0.76792014 0.76721257 0.77500633 0.76364792 0.68742015 0.67555103
#  0.66643574 0.64898669 0.653548   0.63243691 0.63523189 0.60542291
#  0.56992814 0.5714621  0.57655295 0.56130816 0.57614472 0.68628493
#  0.61853656 0.57556865 0.59238718 0.58392109 0.60573805 0.56503826
#  0.54487604 0.49730356 0.49707255 0.47162119 0.46999438 0.44310883
#  0.50170666 0.52909768 0.60521083 0.71537702 0.71504945 0.52779383
#  0.46781171]
# 0.007339_CDDM;relu;N=93;lmbdo=0.3;orth_inp_only=True;lmbdr=0.5;lr=0.005;maxiter=1000
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 18
#      16 print(sf)
#      17 scores1 = [float(LC_folder.split("_")[0]) for LC_folder in LC_folders]
# ---> 18 scores2 = [float(LC_folder.split("_")[1]) for LC_folder in LC_folders]
#      19 pdf = pd.DataFrame({"R2 total" : scores1, "R2 projection" : scores2, "LC_folder_name" : LC_folders})
#      20 pdf = pdf.sort_values(by=['R2 total'], ascending=False)
#
# Cell In[11], line 18, in <listcomp>(.0)
#      16 print(sf)
#      17 scores1 = [float(LC_folder.split("_")[0]) for LC_folder in LC_folders]
# ---> 18 scores2 = [float(LC_folder.split("_")[1]) for LC_folder in LC_folders]
#      19 pdf = pd.DataFrame({"R2 total" : scores1, "R2 projection" : scores2, "LC_folder_name" : LC_folders})
#      20 pdf = pdf.sort_values(by=['R2 total'], ascending=False)
#
# ValueError: could not convert string to float: 'nodes'

# %%
filtered_LC_folders
# Out:
# ['0.0114539_CDDM;relu;N=99;lmbdo=0.3;lmbdr=0.5;lr=0.002;maxiter=3000',
#  '0.011325_CDDM;relu;N=100;lmbdo=0.3;lmbdr=0.5;lr=0.002;maxiter=3000',
#  '0.0128405_CDDM;relu;N=98;lmbdo=0.3;lmbdr=0.5;lr=0.002;maxiter=3000',
#  '0.0116918_CDDM;relu;N=100;lmbdo=0.3;lmbdr=0.5;lr=0.002;maxiter=3000',
#  '0.0134753_CDDM;relu;N=99;lmbdo=0.3;lmbdr=0.5;lr=0.002;maxiter=3000',
#  '0.0113316_CDDM;relu;N=100;lmbdo=0.3;lmbdr=0.5;lr=0.002;maxiter=3000',
#  '0.0104946_CDDM;relu;N=100;lmbdo=0.3;lmbdr=0.5;lr=0.002;maxiter=3000',
#  '0.0123133_CDDM;relu;N=100;lmbdo=0.3;lmbdr=0.5;lr=0.002;maxiter=3000',
#  '0.0117217_CDDM;relu;N=100;lmbdo=0.3;lmbdr=0.5;lr=0.002;maxiter=3000',
#  '0.0115071_CDDM;relu;N=100;lmbdo=0.3;lmbdr=0.5;lr=0.002;maxiter=3000',
#  '0.012049_CDDM;relu;N=99;lmbdo=0.3;lmbdr=0.5;lr=0.002;maxiter=3000',
#  '0.0115656_CDDM;relu;N=100;lmbdo=0.3;lmbdr=0.5;lr=0.002;maxiter=3000',
#  '0.0122573_CDDM;relu;N=100;lmbdo=0.3;lmbdr=0.5;lr=0.002;maxiter=3000',
#  '0.0114762_CDDM;relu;N=100;lmbdo=0.3;lmbdr=0.5;lr=0.002;maxiter=3000',
#  '0.0125186_CDDM;relu;N=100;lmbdo=0.3;lmbdr=0.5;lr=0.002;maxiter=3000',
#  '0.0137156_CDDM;relu;N=100;lmbdo=0.3;lmbdr=0.5;lr=0.002;maxiter=3000',
#  '0.0116997_CDDM;relu;N=100;lmbdo=0.3;lmbdr=0.5;lr=0.002;maxiter=3000',
#  '0.0109851_CDDM;relu;N=100;lmbdo=0.3;lmbdr=0.5;lr=0.002;maxiter=3000',
#  '0.0126345_CDDM;relu;N=100;lmbdo=0.3;lmbdr=0.5;lr=0.002;maxiter=3000',
#  '0.0107927_CDDM;relu;N=100;lmbdo=0.3;lmbdr=0.5;lr=0.002;maxiter=3000']

# %%
qs = []
Us = []
for sf in filtered_LC_folders:
    path_to_subfolder = os.path.join(path_to_folders, sf)
    LC_folders = os.listdir(path_to_subfolder)
#     print(path_to_subfolder)
    if ".DS_Store" in LC_folders:
        LC_folders.remove(".DS_Store")
    scores1 = [float(LC_folder.split("_")[0]) for LC_folder in LC_folders]
    scores2 = [float(LC_folder.split("_")[1]) for LC_folder in LC_folders]
    pdf = pd.DataFrame({"R2 total" : scores1, "R2 projection" : scores2, "LC_folder_name" : LC_folders})
    pdf = pdf.sort_values(by=['R2 total'], ascending=False)
    folders_sorted = list(pdf["LC_folder_name"])
    scores1_sorted = list(pdf["R2 total"])
    scores2_sorted = list(pdf["R2 projection"])
    
    # get the average result across 5 top LCs!
    W_inp = np.zeros((8,6))
    W_rec = np.zeros((8,8))
    W_out = np.zeros((2,8))
    num_nets = 7
    for i in range(num_nets):
        data_file = os.path.join(path_to_subfolder, folders_sorted[i], f"{scores1_sorted[i]}_{scores2_sorted[i]}_LC_params.json")
        data = json.load(open(data_file, "rb+"))
        W_inp += np.array(data["W_inp"])
        W_rec += np.array(data["W_rec"])
        W_out += np.array(data["W_out"])
    W_inp/=num_nets
    W_rec/=num_nets
    W_out/=num_nets
    print(sf)
    print(scores1_sorted[0], scores2_sorted[0])
    
    fig, axs = plt.subplots(1, 3, figsize = (6,2))
    axs[0].imshow(W_inp, cmap = 'coolwarm', vmin=-1, vmax = 1)
    axs[1].imshow(W_rec, cmap = 'coolwarm', vmin=-1, vmax = 1)
    axs[2].imshow(W_out, cmap = 'coolwarm', vmin=-1, vmax = 1)
    plt.show()
# Out:
# 0.0114539_CDDM;relu;N=99;lmbdo=0.3;lmbdr=0.5;lr=0.002;maxiter=3000
# 0.9549780209689057 0.975574030786821
# 0.011325_CDDM;relu;N=100;lmbdo=0.3;lmbdr=0.5;lr=0.002;maxiter=3000
# 0.9563516149290711 0.9738313572216338
# 0.0128405_CDDM;relu;N=98;lmbdo=0.3;lmbdr=0.5;lr=0.002;maxiter=3000
# 0.9616342054589402 0.9806308176300097
# 0.0116918_CDDM;relu;N=100;lmbdo=0.3;lmbdr=0.5;lr=0.002;maxiter=3000
# 0.9560210205982873 0.9774802950175953
# 0.0134753_CDDM;relu;N=99;lmbdo=0.3;lmbdr=0.5;lr=0.002;maxiter=3000
# 0.9591295018561649 0.9810595562888677
# 0.0113316_CDDM;relu;N=100;lmbdo=0.3;lmbdr=0.5;lr=0.002;maxiter=3000
# 0.9454652602856394 0.9688530618872547
# 0.0104946_CDDM;relu;N=100;lmbdo=0.3;lmbdr=0.5;lr=0.002;maxiter=3000
# 0.9563414207283788 0.9782022593261165
# 0.0123133_CDDM;relu;N=100;lmbdo=0.3;lmbdr=0.5;lr=0.002;maxiter=3000
# 0.9655724845452478 0.9819329915668282
# 0.0117217_CDDM;relu;N=100;lmbdo=0.3;lmbdr=0.5;lr=0.002;maxiter=3000
# 0.9585912753178434 0.9743075383422746
# 0.0115071_CDDM;relu;N=100;lmbdo=0.3;lmbdr=0.5;lr=0.002;maxiter=3000
# 0.9534811232348384 0.9755626837467084
# 0.012049_CDDM;relu;N=99;lmbdo=0.3;lmbdr=0.5;lr=0.002;maxiter=3000
# 0.9628133409205232 0.9760172077027853
# 0.0115656_CDDM;relu;N=100;lmbdo=0.3;lmbdr=0.5;lr=0.002;maxiter=3000
# 0.9558284250537737 0.9790316356603015
# 0.0122573_CDDM;relu;N=100;lmbdo=0.3;lmbdr=0.5;lr=0.002;maxiter=3000
# 0.9615519815821196 0.9815039432173633
# 0.0114762_CDDM;relu;N=100;lmbdo=0.3;lmbdr=0.5;lr=0.002;maxiter=3000
# 0.9479927841729067 0.9722874719226829
# 0.0125186_CDDM;relu;N=100;lmbdo=0.3;lmbdr=0.5;lr=0.002;maxiter=3000
# 0.955977647253198 0.9760019631901453
# 0.0137156_CDDM;relu;N=100;lmbdo=0.3;lmbdr=0.5;lr=0.002;maxiter=3000
# 0.9626249018237748 0.9777077761085462
# 0.0116997_CDDM;relu;N=100;lmbdo=0.3;lmbdr=0.5;lr=0.002;maxiter=3000
# 0.9568773365527923 0.9791399370089953
# 0.0109851_CDDM;relu;N=100;lmbdo=0.3;lmbdr=0.5;lr=0.002;maxiter=3000
# 0.9495329290804819 0.9732956860253265
# 0.0126345_CDDM;relu;N=100;lmbdo=0.3;lmbdr=0.5;lr=0.002;maxiter=3000
# 0.9585521121392963 0.9817549201425594
# 0.0107927_CDDM;relu;N=100;lmbdo=0.3;lmbdr=0.5;lr=0.002;maxiter=3000
# 0.9510649408169416 0.9784944748744295
# 0.0115637_CDDM;relu;N=100;lmbdo=0.3;lmbdr=0.5;lr=0.002;maxiter=3000
# 0.9498678175944091 0.9726127768539643
# 0.0126643_CDDM;relu;N=100;lmbdo=0.3;lmbdr=0.5;lr=0.002;maxiter=3000
# 0.96063884021597 0.9801600571166146
# 0.013814_CDDM;relu;N=100;lmbdo=0.3;lmbdr=0.5;lr=0.002;maxiter=3000
# 0.9600104030937291 0.9779047163304576
# 0.0119984_CDDM;relu;N=100;lmbdo=0.3;lmbdr=0.5;lr=0.002;maxiter=3000
# 0.9635620628726089 0.9834229431402801
# 0.0108408_CDDM;relu;N=100;lmbdo=0.3;lmbdr=0.5;lr=0.002;maxiter=3000
# 0.9391455076274954 0.965690896731677
# 0.009868_CDDM;relu;N=100;lmbdo=0.3;lmbdr=0.5;lr=0.002;maxiter=3000
# 0.9480553859728326 0.9771410857055133
# 0.0120123_CDDM;relu;N=100;lmbdo=0.3;lmbdr=0.5;lr=0.002;maxiter=3000
# 0.9624270838564699 0.9795260847688029
# 0.0128737_CDDM;relu;N=100;lmbdo=0.3;lmbdr=0.5;lr=0.002;maxiter=3000
# 0.9545589893569246 0.9796912830710927
# 0.0118682_CDDM;relu;N=100;lmbdo=0.3;lmbdr=0.5;lr=0.002;maxiter=3000
# 0.9587716218623538 0.9787513893363035
# 0.0101195_CDDM;relu;N=100;lmbdo=0.3;lmbdr=0.5;lr=0.002;maxiter=3000
# 0.9533754972246434 0.9762046252371703
# 0.0115276_CDDM;relu;N=99;lmbdo=0.3;lmbdr=0.5;lr=0.002;maxiter=3000
# 0.9610086264429366 0.9767644333963019
# 0.0117245_CDDM;relu;N=100;lmbdo=0.3;lmbdr=0.5;lr=0.002;maxiter=3000
# 0.9528522784600248 0.9783661049224053
# 0.0112458_CDDM;relu;N=100;lmbdo=0.3;lmbdr=0.5;lr=0.002;maxiter=3000
# 0.9594344250825655 0.9783140502236649
# 0.0119141_CDDM;relu;N=100;lmbdo=0.3;lmbdr=0.5;lr=0.002;maxiter=3000
# 0.958102574679528 0.9778978255694872
# 0.0119775_CDDM;relu;N=100;lmbdo=0.3;lmbdr=0.5;lr=0.002;maxiter=3000
# 0.9609099256598633 0.9802371657833938
# 0.0120953_CDDM;relu;N=99;lmbdo=0.3;lmbdr=0.5;lr=0.002;maxiter=3000
# 0.9637822976152987 0.9820718172618597
# 0.0112686_CDDM;relu;N=100;lmbdo=0.3;lmbdr=0.5;lr=0.002;maxiter=3000
# 0.9550543885450561 0.9742912690072274
# 0.0115183_CDDM;relu;N=100;lmbdo=0.3;lmbdr=0.5;lr=0.002;maxiter=3000
# 0.9573766960501022 0.9813464448953514
# 0.0113589_CDDM;relu;N=99;lmbdo=0.3;lmbdr=0.5;lr=0.002;maxiter=3000
# 0.9563193872209625 0.9750529980511784
# 0.0131271_CDDM;relu;N=100;lmbdo=0.3;lmbdr=0.5;lr=0.002;maxiter=3000
# 0.9626978396312245 0.9806416772386342
# 0.0109402_CDDM;relu;N=100;lmbdo=0.3;lmbdr=0.5;lr=0.002;maxiter=3000
# 0.9507110721527127 0.9703998033195551
# 0.0118542_CDDM;relu;N=100;lmbdo=0.3;lmbdr=0.5;lr=0.002;maxiter=3000
# 0.9590574129990831 0.9802361740241391
# 0.0110356_CDDM;relu;N=100;lmbdo=0.3;lmbdr=0.5;lr=0.002;maxiter=3000
# 0.9476040877060073 0.9763415406903362
# 0.0100262_CDDM;relu;N=100;lmbdo=0.3;lmbdr=0.5;lr=0.002;maxiter=3000
# 0.9579161351580874 0.979578857113284
# 0.0108476_CDDM;relu;N=100;lmbdo=0.3;lmbdr=0.5;lr=0.002;maxiter=3000
# 0.9571977157184123 0.9788132681473757
# 0.0110157_CDDM;relu;N=100;lmbdo=0.3;lmbdr=0.5;lr=0.002;maxiter=3000
# 0.
lmbdo=0.3;lmbdr=0.5;lr=0.002;maxiter=3000
# 0.9527318363110763 0.9719248962589545
# 0.0117279_CDDM;relu;N=99;lmbdo=0.3;lmbdr=0.5;lr=0.002;maxiter=3000
# 0.9587149827070818 0.9785867139584693

# %%
nets_to_study = filtered_LC_folders

# %%
w_recs = []
w_outs = []
w_inps = []
W_recs = []
W_outs = []
W_inps = []
Qs = []
for sf in nets_to_study:
    path_to_subfolder = os.path.join(path_to_folders, sf)
    LC_folders = os.listdir(path_to_subfolder)
#     print(path_to_subfolder)
    if ".DS_Store" in LC_folders:
        LC_folders.remove(".DS_Store")
    scores1 = [float(LC_folder.split("_")[0]) for LC_folder in LC_folders]
    scores2 = [float(LC_folder.split("_")[1]) for LC_folder in LC_folders]
    pdf = pd.DataFrame({"R2 total" : scores1, "R2 projection" : scores2, "LC_folder_name" : LC_folders})
    pdf = pdf.sort_values(by=['R2 total'], ascending=False)
    folders_sorted = list(pdf["LC_folder_name"])
    scores1_sorted = list(pdf["R2 total"])
    scores2_sorted = list(pdf["R2 projection"])

    data_file = os.path.join(path_to_subfolder, folders_sorted[0], f"{scores1_sorted[0]}_{scores2_sorted[0]}_LC_params.json")
    data = json.load(open(data_file, "rb+"))
    w_inp = np.array(data["W_inp"])
    w_rec = np.array(data["W_rec"])
    w_out = np.array(data["W_out"])
    U = np.array(data["U"])
    q = np.array(data["q"])
    Q = U.T @ q
    w_inps.append(deepcopy(W_inp))
    w_recs.append(deepcopy(W_rec))
    w_outs.append(deepcopy(W_out))
    Qs.append(deepcopy(Q))
    rnn_score = float(sf.split("_")[0])
    
    rnn_config_file = os.path.join(path_to_subfolder, folders_sorted[0], f"{rnn_score}_params_CDDM.json")
    
    data_RNN = json.load(open(rnn_config_file, "rb+"))
    W_inp = np.array(data_RNN["W_inp"])
    W_rec = np.array(data_RNN["W_rec"])
    W_out = np.array(data_RNN["W_out"])
    W_inps.append(deepcopy(W_inp))
    W_recs.append(deepcopy(W_rec))
    W_outs.append(deepcopy(W_out))

# %%
j = 0
fig, axs = plt.subplots(1, 4, figsize = (10,10))
axs[0].imshow(W_inps[j], cmap = 'coolwarm', vmin=-1, vmax = 1)
axs[1].imshow(W_outs[j].T, cmap = 'coolwarm', vmin=-1, vmax = 1)
axs[2].imshow(Qs[j], cmap = 'coolwarm', vmin=-1, vmax = 1)
axs[3].imshow(W_recs[j], cmap = 'coolwarm', vmin=-0.5, vmax = 0.5)
axs[3].set_aspect(4.1, adjustable='box')
plt.tight_layout()
plt.subplots_adjust(wspace = 0, hspace = 0)
plt.show()
# Out:
# /var/folders/xg/zhs696691j905z_h1c8w8wvh0000gp/T/ipykernel_69193/2146366435.py:9: UserWarning: This figure was using a layout engine that is incompatible with subplots_adjust and/or tight_layout; not calling subplots_adjust.
#   plt.subplots_adjust(wspace = 0, hspace = 0)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=3)
pca.fit(W_inps[j])
# Out:
# PCA(n_components=3)

# %%
for i in range(len(W_outs)):
    plt.plot(np.sort(np.sum(W_outs[i], axis = 0))[::-1], alpha = 0.1, color = 'k')

# %% [markdown]
# # the inputs are not uniform!

# %%
mat = W_inps[j]@ pca.components_.T
fig, axs = plt.subplots(1, 3, figsize = (8,3))
axs[0].scatter(mat[:, 0], mat[:, 1], color = 'r', edgecolor = 'k')
axs[1].scatter(mat[:, 0], mat[:, 2], color = 'r', edgecolor = 'k')
axs[2].scatter(mat[:, 1], mat[:, 2], color = 'r', edgecolor = 'k')
plt.show()

# %% [markdown]
# # need to check the clustering of the original traces of the RNN
#
# TODO (need to save trajectories as a separate file! I don't want to rerun it constantly)
